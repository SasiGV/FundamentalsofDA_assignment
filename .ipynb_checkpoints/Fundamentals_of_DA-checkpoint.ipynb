# %% [markdown]
# # Fundamentals of DataAnalysis
# ### Project for Semester 2 - 2019
# ### Student Name : Sasikala Varatharajan
# ### Student Number : G00376470
#
# ## Project Topic :Assessment on Tips Dataset

# %% [markdown]
# ## 1.1  Importing the libraries for this project: Numpy, Matplotlib, Pandas and Seaborn
#
# NumPy is the fundamental package for scientific computing with Python
#
# Matplotlib is a Pythod 2D plotting library for the Python programming language and its numerical mathematics extension NumPy.
#
# Pandas is an open source, BSD-licensed library providing high-performance, easy-to-use data structures and data analysis tools.
#
# Seaborn is a Python visualization library based on matplotlib. It provides a high-level interface for drawing attractive statistical graphics.

# %%
# Code to import python libraries and the 'tips' dataset

# import numpy for use of arrays
import numpy as np

# import matplotlib pyplot for ploting
import matplotlib.pyplot as plt

# import pandas to use Dataframes for the dataset
import pandas as pd

# import seaborn for ploting and loading tips dataset
import seaborn as sns

#import 'tips' dataset from seaborn module
tips = sns.load_dataset("tips")

# %% [markdown]
# ## 1. Purpose of this package
#
# For this Assignment I have taken the wellknown dataset called 'tips' which has the variables total_bill, tip, sex, smoker, day, time and size. By applying various functions covered in Fundamentals of Data Analysis subject we are going to find the relationship between the variables in this dataset. For my analysis I am using different plots to show how the other factors impacts the tips at various stages by different set of people.
#
# We can use the basic functionalities to see sample data from the dataset.

# %%
# Code to show the first 5 lines from the dataset

print("Firt 5 lines from the 'tips' dataset")
tips.head()
# Out:
# Firt 5 lines from the 'tips' dataset
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
# code to show the last five lines from the dataset

print ("Last 5 lines from the 'tips' dataset")
tips.tail()
# Out:
# Last 5 lines from the 'tips' dataset
#      total_bill   tip     sex smoker   day    time  size
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2

# %%
# Discover the shape of the dataset
tips.shape
# Out:
# (244, 7)

# %% [markdown]
# Based on the above results it seems that the dataset includes 244 observations for 7 different variables over a period of time from a restuarant. This could be taken by one waiter or by a number of waiters. A number of sources from internet describes that this data could be taken by one waiter and the variable 'Sex' is related to the gender of the waiter or it could be related to the Payer/customer.
#
# From my point of view all the variables looks like related to the customer/payer as there is a connection between each variable. Variables  total_bill and tip are related to the payment and the variables Sex and Smoker are related to the Payer/Customer. Finally the remaining variables day, time and size are related to the restuarent.

# %% [markdown]
# # 2. Explain Discriptive Statistics

# %% [markdown]
# Statistics is a branch of applied mathematics that provides methods and tools to collect, analyse, present and interpret data and to make decisions. Basically Statistics is about stydying the data and based on the analysis we can take make educated estimates about the collection of data. One of the main areas in Statistics is Descriptive Statistics.
#
# A data set is a collection of one or more variables. Discriptive Statistics is used to display and describe data by using tables graphs and summary measures. It is also useful to understand large amount of data by providing methods to summarise data.
#
# There are two ways to Descriptive Statistics: Numerical and Graphical.
#
# #### Numerical Methods:
#
# Measures of Frequency : Count, Percent and Frequency
#
# Measures of Central Tendency: Mean Median and Mode
#
# Measures of Dispersion: Variance, Standard Deviation, Range and IQR.
#
#
# #### Graphical Methods:
#
# Univariate Data: Histograms, Pie Chart, Bar plots
#
# Bivariate Data: Boxplot, Scatterplot
#
# Multivariate Data: Biplots Clustering

# %% [markdown]
# ## Measures of Frequency
#
# Frequency statistics simply count the number of times that each variable occurs. With this frequency we can show how often an event occurs.

# %% [markdown]
# From the examples below I have take the Variable 'Sex' to show the count and percentage of occurances in the dataset. Second example shows the count of both 'Sex' types on each day.

# %%
s = tips.sex
Counts = s.value_counts()

percent = s.value_counts(normalize=True).mul(100).round(1).astype(str) + '%'
pd.DataFrame({'Counts' : Counts, 'Percent' : percent})
# Out:
#         Counts Percent
# Male       157   64.3%
# Female      87   35.7%

# %%
df = sns.load_dataset("tips")
props = df.groupby("day")['sex'].value_counts(normalize=True).unstack()
props.plot(kind='bar' , stacked='True')

# %% [markdown]
# ## Measures of Central Tendency: Mean Median and Mode

# %% [markdown]
# A measure of central tendency is a summary statistic that represets the center point or typical value of a dataset. These measures indicate where most vales in a distribution fall and are also referred to as the central location of distribution. Measures of cetral tendency are often called averates.
#
# ###### Mean :
# It is the most frequently used one and generally considered the best measure of it. It is equal to the sum of all the values in the data set divied by the number of values in the data set.
#
# ###### Median :
# This is the middle score for the set of data that has been arranged from smallest. If the data set has even number of items then the median will be the averate of the result.
#
# ###### Mode :
# Mode is the most frequent score in the data set. This measure is mostely used to find out the most common category from the data set.

# %% [markdown]
# For example, I have taken one of the variables 'tip' to find Mean, Meadian and Mode

# %%
# code to find Mean of the variable 'tip'
tips["tip"].mean()
# Out:
# 2.9982786885245902

# %%
# code to find Median of the variable 'tip'
tips["tip"].median()
# Out:
# 2.9

# %%
# code to find mode of the variable 'tip'
tips["tip"].mode()
# Out:
# 0    2.0
# dtype: float64

# %% [markdown]
# We can also use groupby method to group the data by selected variable.

# %%
# code to group the tips dataset by the variable sex and get the first 10 lines
Sex_Group = tips.groupby("sex")
Sex_Group.head()
# Out:
#     total_bill   tip     sex smoker  day    time  size
# 0        16.99  1.01  Female     No  Sun  Dinner     2
# 1        10.34  1.66    Male     No  Sun  Dinner     3
# 2        21.01  3.50    Male     No  Sun  Dinner     3
# 3        23.68  3.31    Male     No  Sun  Dinner     2
# 4        24.59  3.61  Female     No  Sun  Dinner     4
# 5        25.29  4.71    Male     No  Sun  Dinner     4
# 6         8.77  2.00    Male     No  Sun  Dinner     2
# 11       35.26  5.00  Female     No  Sun  Dinner     4
# 14       14.83  3.02  Female     No  Sun  Dinner     2
# 16       10.33  1.67  Female     No  Sun  Dinner     3

# %%
# code to get the last 2 lines
Sex_Group.last()
# Out:
#         total_bill   tip smoker   day    time  size
# sex
# Male         17.82  1.75     No   Sat  Dinner     2
# Female       18.78  3.00     No  Thur  Dinner     2

# %%
# code to get the sum of the variable. In this case the variable Sex has two different unique values. 
# so that we will get two sets of data
Sex_Group.sum()
# Out:
#         total_bill     tip  size
# sex
# Male       3256.82  485.07   413
# Female     1570.95  246.51   214

# %%
Sex_Group.mean()
# Out:
#         total_bill       tip      size
# sex
# Male     20.744076  3.089618  2.630573
# Female   18.056897  2.833448  2.459770

# %%
# code to show average mean for total bill amount
tips['total_bill'].mean()
# Out:
# 19.785942622950824

# %%
#code to show average mean for tip amount
tips['tip'].mean()
# Out:
# 2.9982786885245902

# %%
Sex_Group.median()
# Out:
#         total_bill   tip  size
# sex
# Male         18.35  3.00     2
# Female       16.40  2.75     2

# %% [markdown]
# ## Measures of Dispersion
#
# Measures of dispersion describes the spread of Data around the central value (mean, median or mode). Range, Variance and Standard deviation are the most common methods.
#
# Range is the difference between the largest and smallest values in the dataset.  Variance used to measure how far a dataset is spread out. It is calculated by taking the averate of the squared differences betwen each value and the mean.  Standard deviation is basically the square root of variance.

# %%
# code to find standard deviation
tips.std()
# Out:
# total_bill    8.902412
# tip           1.383638
# size          0.951100
# dtype: float64

# %%
# code to find variance
tips.var(ddof=0)
# Out:
# total_bill    78.928131
# tip            1.906609
# size           0.900883
# dtype: float64

# %%
# code to find the mean (avearage) absolute deviation
tips.mad()
# Out:
# total_bill    6.869440
# tip           1.033019
# size          0.779898
# dtype: float64

# %%
# This code describes some basis statistics about the dataset.

# Print heading
print("Basic 'tips' dataset statistics")
# Print dataset statistics
tips.describe()
# Out:
# Basic 'tips' dataset statistics
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %% [markdown]
# ## Review using different measurements

# %%
# Print Title
print("Breakdown of number of people visited in a day")

# Code adapted from https://dfrieds.com/data-analysis/crosstabs-python-pandas
pd.crosstab(index=tips['day'], columns=tips['sex'], margins=True)
# Out:
# Breakdown of number of people visited in a day
# sex   Male  Female  All
# day
# Thur    30      32   62
# Fri     10       9   19
# Sat     59      28   87
# Sun     58      18   76
# All    157      87  244

# %%
# Print Title
print("Breakdown of smokers visited in a day")

# Code adapted from https://dfrieds.com/data-analysis/crosstabs-python-pandas
pd.crosstab(index=tips['sex'], columns=tips['smoker'], margins=True)
# Out:
# Breakdown of smokers visited in a day
# smoker  Yes   No  All
# sex
# Male     60   97  157
# Female   33   54   87
# All      93  151  244

# %%
# Print Title
print("Breakdown of number of people visited in a day using Groupby ")

# Code adapted from https://dfrieds.com/data-analysis/crosstabs-python-pandastips.groupby(['day', 'sex'])['time'].count()
tips.groupby(['day', 'sex'])['time'].count()
# Out:
# Breakdown of number of people visited in a day using Groupby
# day   sex
# Thur  Male      30
#       Female    32
# Fri   Male      10
#       Female     9
# Sat   Male      59
#       Female    28
# Sun   Male      58
#       Female    18
# Name: time, dtype: int64

# %%
# Print heading
print("Percentage of Male/Female visited in a day")
#Display counts of occurance as percentages of total # of observations

# Code adapted from https://stackoverflow.com/a/26050459 and
# https://dfrieds.com/data-analysis/crosstabs-python-pandas
pd.crosstab(index=tips['day'], columns=tips['sex'], margins=True).rename(
    columns={"Male": "%_Male", "Female": "%_Female"}).apply(
    lambda row: np.round(100*row/len(tips),1), axis=1)
# Out:
# Percentage of Male/Female visited in a day
# sex   %_Male  %_Female    All
# day
# Thur    12.3      13.1   25.4
# Fri      4.1       3.7    7.8
# Sat     24.2      11.5   35.7
# Sun     23.8       7.4   31.1
# All     64.3      35.7  100.0

# %%
# Print Title
print("Breakdown of number of people visited in a day ")

# Code adapted from https://dfrieds.com/data-analysis/crosstabs-python-pandastips.groupby(['day', 'sex'])['time'].count()

pd.crosstab(index=tips['day'], columns=tips['sex'], colnames=['gender'], margins=True, margins_name="count_meals_served").rename(columns={"Male": "count_meals_served_for_male_Payer", "Female": "count_meals_served_for_females_payer"})
# Out:
# Breakdown of number of people visited in a day
# gender              count_meals_served_for_male_Payer  \
# day
# Thur                                               30
# Fri                                                10
# Sat                                                59
# Sun                                                58
# count_meals_served                                157
#
# gender              count_meals_served_for_females_payer  count_meals_served
# day
# Thur                                                  32                  62
# Fri                                                    9                  19
# Sat                                                   28                  87
# Sun                                                   18                  76
# count_meals_served                                    87                 244

# %% [markdown]
# From the above basic statistis on the 'tips' dataset shows that the 244 observations were recorded on only 4 days of the week. These four days falls on weekend which would be the busy days in a week. Most of the restuarent businesses will prefer to take off in the non-busy days such as Monday and Tuesdays. And also the observarions shows that Saturday is the busy day with most meals served where as Fridday is the day with lowest meal count. The majority of the bill paying patrons are non-smoking males. The average/mean total_bill and tip are \$19.79 and \\$3.00 respectively.

# %% [markdown]
# The following example is used to show a number of paired comparisons for the numerical values in the 'tips' dataset using the seaborn plots.
#
# We can use distplot function to show the distribution of tips from the dataset

# %%
#code to show the distribution of tips 

#code adapted from https://data-and-design.readthedocs.io/en/latest/02-introPandas.html?fireglass_rsn=true
print ("Distributuon of Tips on the Days")
sns.distplot(tips["tip"])
# Out:
# Distributuon of Tips on the Days
# C:\Users\charm\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
# Plot multiplot of numerical data

# Code adpated from https://seaborn.pydata.org/generated/seaborn.pairplot.html
plot = sns.pairplot(tips, hue="day")

plt.subplots_adjust(top=0.95)
plt.suptitle("Plot pairwise relationships from tips dataset", fontsize = 20)
plt.show()

# %% [markdown]
# ## 3. Regression
#
# Regression analysis is a powerful statistical method to examine the relationship between two or more variables from the dataset. This analysis is a most reliable method to identify which variables have impact on another variable or on the dataset. This method will allow us to determine which factors matter most, which can be ignored and how there factors influence each other.
#
# Dependent variable: This is the main factor that you're trying to understand or predict.
#
# Independent variable: These are the factors that you are hypothesize have an impact on your dependent variable.
#
# From the tips dataset, based on the customers satisfaction we can consider tip is our dependent variable. Other variables total_bill, Sex, time and smoker are our independent variables.
#
# In order to compare the variables I have taken the function Implot() from seaborn as it has data as a required parameter and the x and y variables must be specified as strings. This data format is called “long-form” or “tidy” data.

# %%
# code to draw scatterplot to show total bill and tip
sns.lmplot(x="total_bill", y="tip", data=tips);

# %% [markdown]
# The above example shows that the tip received for each total_bill is directly proportional to the amount of the bill, which can be approximated by the equation.

# %%
# code to draw scatterplot to show size and tip
sns.lmplot(x="size", y="tip", data=tips);

# %% [markdown]
# The above scatterplot is one of the example for liner regression when one the variables takes discrete values. In order to make the distribution of values more clear we can add some random noise ("jitter") to the discrete values but this will not make any influence on the regression line.

# %%
sns.lmplot(x="size", y="tip", data=tips, x_jitter=.05);

# %% [markdown]
# One more option is to collapse over the observations in each discrete bin to plot an estimate of central tendency along with a confidence interval.

# %%
sns.lmplot(x="size", y="tip", data=tips, x_estimator=np.mean);

# %% [markdown]
# The above plots shows the relationship between size and tip of the dataset.  These are the examples to show the relationship between a pair of variables. In order to do more analysis we will have to find the relationship between more than one variable. By doing this we can find the impact of one variable on the other two variables. To achive this we can use regplot() and Import() funcitons.
#
# lmplot() function is used to combine regplot() with FacetGrid to provide an easy interface to show a linear regression on “faceted” plots that allow you to explore interactions with up to three additional categorical variables.
#
# The best way to separate out a relationship is to plot both levels on the same axes and to use color to distinguish them:

# %%
sns.lmplot(x="total_bill", y="tip", hue="smoker", data=tips);

# %% [markdown]
# The above scatterplot shows smokerss with blue color dots are little more generous but not so consistent with their tipping habit as the data points are vaguely spread out. We can separate the plots into different facets like below to make it bit more clear.

# %%
sns.lmplot(x="total_bill", y="tip", hue="smoker", col="time", data=tips);

# %% [markdown]
# As per my assumption earlier time and sex/gender is also  one of the independent variables. So now can expand the optional parameter in the plot function to show all of the variables.

# %%
sns.lmplot(x="total_bill", y="tip", hue="smoker",
           col="time", row="sex", data=tips);

# %% [markdown]
# Based on the above plots we can clearly see how the other factors affects or explains the impact of tip amount on the total bill. We can see that the tip given by the smokers during dinner time is higher than the tip given by smokers during lunch time. Also while comparing the top and bottom plots we can see that how the gender factor affects the scenario.

# %%
sns.lmplot(x="total_bill", y="tip", col="day", data=tips,
           col_wrap=2, height=3);

# %% [markdown]
# Based on the above regression plots we can see that the tip on Saturday is slightly higher than the remaining days.

# %%
#code adapted from  https://seaborn.pydata.org/tutorial/regression.html
sns.jointplot(x="total_bill", y="tip", data=tips, kind="reg");

# Add Title adapted from https://stackoverflow.com/a/52096280
plt.subplots_adjust(top=0.95)
plt.suptitle("Distribution of total_bill and tips", fontsize = 16)
# Display plot
plt.show()

# %% [markdown]
# The plot above shows that the tip received is directly proportional to the amount of the total bill, which can be approximated by the equation.

# %% [markdown]
# ## 4.Analyse
#
# using various methods of plots and functions we can find the impact of tip variable on the total-bill and by grouping other variables we can see how they affect the tip at what level. We can start with single variable distribution and expand the analyse using grouping the variables.
#
# First I have taken the tip variable to show its distribution.

# %%
# The following code reviews the tip percentage compared to the total_bill

# Calculate tip percentage of total_bill. Code adapted from
# https://seaborn.pydata.org/generated/seaborn.pairplot.html
tip_percent = tips.apply(lambda row: np.round(100*row.tip/row.total_bill,0), axis=1)

# Display the min, max, mean and median tip %
print("Tip % (tip/total_bill) summary: Max {:.0f}%, Min {:.0f}%, Mean {:.0f}% & Median {:.0f}%.".format(
       tip_percent.max(), tip_percent.min(), tip_percent.mean(), tip_percent.median()))

# Set figure size Code adapted from
# https://www.drawingfromdata.com/setting-figure-size-using-seaborn-and-matplotlib
plt.figure(figsize=(10,7))

# Plot distribution of tip percentages
# Code adapted from http://seaborn.pydata.org/generated/seaborn.distplot.html
plot = sns.distplot(tip_percent, axlabel="Tip %", color='m')

# Add Title adapted from https://stackoverflow.com/a/52096280
plt.suptitle("Distribution of tip %", fontsize = 16)
plt.show()
# Out:
# Tip % (tip/total_bill) summary: Max 71%, Min 4%, Mean 16% & Median 16%.

# %% [markdown]
# Now we can use two different plots to show how the gender factor affects the tip distribution

# %%
# Plot distribution of sex and tip distribution
# Code adapted from http://seaborn.pydata.org/generated/seaborn.distplot.html

# Temporary variable for Make and Femake 
male = tips.loc[tips["sex"] == "Male", ["sex", "tip"]]
female = tips.loc[tips["sex"] == "Female", ["sex", "tip"]]

male.head()
# Out:
#     sex   tip
# 1  Male  1.66
# 2  Male  3.50
# 3  Male  3.31
# 5  Male  4.71
# 6  Male  2.00

# %%
female.head()
# Out:
#        sex   tip
# 0   Female  1.01
# 4   Female  3.61
# 11  Female  5.00
# 14  Female  3.02
# 16  Female  1.67

# %%
# Plot distribution of tip based on sex/gender variable
sns.distplot(male["tip"])
sns.distplot(female["tip"])

# %%
# use boxplot to show the distribution of tips based on sex/gender variable
sns.boxplot(x = "sex",y = "tip", data = tips )

# %%
# Display relative plot of total_bill paid by either sex and if they were a smoker
# Code adapted from https://seaborn.pydata.org/introduction.html and
# https://seaborn.pydata.org/generated/seaborn.relplot.html
plot = sns.relplot(x="total_bill", y="tip", col="smoker",
            style="sex", hue="sex", data=tips);


plt.subplots_adjust(top=0.9)
plt.suptitle("Comparison of Smoker and Non-Smoker", fontsize = 16)
plt.show()

# %%
# Display relative plot of total_bill paid by smoker based on the party size
# Code adapted from https://seaborn.pydata.org/introduction.html and
# https://seaborn.pydata.org/generated/seaborn.relplot.html
plot = sns.relplot(x="total_bill", y="tip", col="smoker",
            style="size", hue="size", data=tips);


plt.subplots_adjust(top=0.9)
plt.suptitle("Comparison of Smoker and Non-Smoker by size of the party", fontsize = 16)
plt.show()

# %% [markdown]
# From the above plots, data points for tips received are more proportional to the cost of the total bill. Data points for smoker is also more scattered. So that we can see that it could be depend on gender and size of the party but we can see that there is no direct impact to the tip amount. But we can not say that smokers will not be interested in giving tip. They could be because smokers may choose to spend on smoking rather than tipping.

# %%
 # Set figure size Code adapted from
# https://www.drawingfromdata.com/setting-figure-size-using-seaborn-and-matplotlib
plt.figure(figsize=(10,7))

# Plot party_size counts on each day. Code adapted from
# https://seaborn.pydata.org/generated/seaborn.countplot.html
plot = sns.countplot(x="size", data=tips, hue="day")


plt.suptitle("Party size counts on each day", fontsize = 16)
plt.show()

# %%
# Print Title
print("Party size statistics")
# Print party_size counts on each day
pd.crosstab(index=tips['size'], columns=tips['day'], margins=True)
# Out:
# Party size statistics
# day   Thur  Fri  Sat  Sun  All
# size
# 1        1    1    2    0    4
# 2       48   16   53   39  156
# 3        4    1   18   15   38
# 4        5    1   13   18   37
# 5        1    0    1    3    5
# 6        3    0    0    1    4
# All     62   19   87   76  244

# %% [markdown]
# From the above plots we can see that the party/table size is 2 on saturdays has the highest count. We can also notice that the restuarent is used to be busy with table size 2 and very rarely it gets the table with 6 people. Based on the above table it seems that Saturday has the highest number of customers and Friday has the lowest count of tables.
#
# Expanding the analysis based on the party size along with smoker type to figure out how this factor impacts tips on the total bill. I have taken two different plots to show smokers tip based on the party size and non-smokers tip based on the party size. From the plots below we can see that the average tip given by the smokers is higher than the average tip given by the non-smokers.

# %%
# In order to avoid attribute error changing the column name of 'size' to 'party_size'

# Change Dataframe column header label 'size' to 'party_size'
# Code adapted from https://stackoverflow.com/questions/11346283/renaming-columns-in-pandas
temptips = sns.load_dataset("tips")
temptips.rename(columns={'size': 'party_size'}, inplace=True)

# %%
# Temp variable for smoker tip values

smoker_tip_size=(temptips.tip.loc[temptips.loc[:,'smoker'] == "Yes"]/
                 temptips.party_size.loc[temptips.loc[:,'smoker'] == "Yes"])


# Display the min, max and mean tip from smokers adjusted for party_size
print("""
Tip summary from smokers adjusted for party_size:
Max {:.2f}, Min {:.2f}, Mean {:.2f} and Median {:.2f}.
""".format(smoker_tip_size.max(),smoker_tip_size.min(),
           smoker_tip_size.mean(),smoker_tip_size.median()))

# Set figure size Code adapted from
# https://www.drawingfromdata.com/setting-figure-size-using-seaborn-and-matplotlib
plt.figure(figsize=(10,7))

# Plot distribution of tips from smokers adjusted for party_size
# Code adapted from https://seaborn.pydata.org/generated/seaborn.distplot.html
plot = sns.distplot(smoker_tip_size, color='r',
                    axlabel="Smoker tip adjusted for Party_Size")

plt.suptitle("Distritubtion of Smoker tip adjusted for Party size", fontsize = 16)
plt.show()
# Out:
# Tip summary from smokers adjusted for party_size:
# Max 3.33, Min 0.40, Mean 1.30 and Median 1.17.

# %%
# Temp variable for non-smoker tip values

non_smoker_tip_size=(temptips.tip.loc[temptips.loc[:,'smoker'] == "No"]/
                 temptips.party_size.loc[temptips.loc[:,'smoker'] == "No"])


# Display the min, max and mean tip from smokers adjusted for party_size
print("""
Tip summary from smokers adjusted for party_size:
Max {:.2f}, Min {:.2f}, Mean {:.2f} and Median {:.2f}.
""".format(non_smoker_tip_size.max(),non_smoker_tip_size.min(),
           non_smoker_tip_size.mean(),non_smoker_tip_size.median()))

# Set figure size Code adapted from
# https://www.drawingfromdata.com/setting-figure-size-using-seaborn-and-matplotlib
plt.figure(figsize=(10,7))

# Plot distribution of tips from smokers adjusted for party_size
# Code adapted from https://seaborn.pydata.org/generated/seaborn.distplot.html
plot = sns.distplot(non_smoker_tip_size, color='r',
                    axlabel="Non Smoker tip adjusted for Party Size")

plt.suptitle("Distritubtion of Non Smoker tip adjusted for Party size", fontsize = 16)
plt.show()
# Out:
# Tip summary from smokers adjusted for party_size:
# Max 2.92, Min 0.45, Mean 1.16 and Median 1.05.

# %%
# code to group the tips dataset by smoker
# code adapted from https://www.datacamp.com/community/tutorials/pandas-multi-index?fireglass_rsn=true
df = tips.groupby('smoker').mean()
df
# Out:
#         total_bill       tip      size
# smoker
# Yes      20.756344  3.008710  2.408602
# No       19.188278  2.991854  2.668874

# %% [markdown]
# From the above example once again we can prove that tips given by smokers is higher than the tips given by non smokers. Above sample has one more column with size which also shows tips given by smokers at table with 2 people has the highest rate.

# %%
# code to group the tips dataset by smoker and time
# code adapted from https://www.datacamp.com/community/tutorials/pandas-multi-index?fireglass_rsn=true
df = tips.groupby(['smoker','time']).mean()
df
# Out:
#                total_bill       tip      size
# smoker time
# Yes    Lunch    17.399130  2.834348  2.217391
#        Dinner   21.859429  3.066000  2.471429
# No     Lunch    17.050889  2.673778  2.511111
#        Dinner   20.095660  3.126887  2.735849

# %% [markdown]
# The above grouping help us to get bit more clear data based on the meal time to decide whos tip amount at what meal time has the highest rate. From the above results it is clearly seems that the tip given by smokers at dinner time with party size 2 has the highest rate.
#
# Now I am changing the independent variables to analyse the impact on tips by meam time and total bill amount

# %%
# Plot Daily split of total-bill grouped by meal time
# Set figure size Code adapted from
# https://www.drawingfromdata.com/setting-figure-size-using-seaborn-and-matplotlib
plt.figure(figsize=(10,7))


# Code adapted from https://seaborn.pydata.org/generated/seaborn.boxplot.html
plot = sns.boxplot(x="day", y="total_bill", data=tips, hue="time")


plt.suptitle("Daily split of total_bill grouped by meal time", fontsize = 16)
plt.show()

# %%
# Plot Daily split of tips
# Set figure size Code adapted from
# https://www.drawingfromdata.com/setting-figure-size-using-seaborn-and-matplotlib
plt.figure(figsize=(10,7))

# Code adapted from https://seaborn.pydata.org/generated/seaborn.color_palette.html#seaborn.color_palette
plot = sns.boxplot(x="day", y="tip", data=tips, palette="husl")

plt.suptitle("Daily split of tips", fontsize = 16)
plt.show()

# %%
# Print daily sums for total_bill and tip
# Code adapted from https://www.youtube.com/watch?v=_T8LGqJtuGc
# and https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.pivot_table.html
day_paid = tips.pivot_table(['total_bill','tip'], columns='day', aggfunc='sum')
# Print the daily sum
print("Daily sum of total_bill and tip")
day_paid
# Out:
# Daily sum of total_bill and tip
# day            Thur     Fri     Sat      Sun
# tip          171.83   51.96   260.4   247.39
# total_bill  1096.33  325.88  1778.4  1627.16

# %% [markdown]
# From the above two diffent daily split of the meals statistics it is clearly seems that the Lunch time is the main meal time on Thursday, there are mixed meal times on Friday and Saturday and Sunday has only one meal time which is Dinner time. The daily sum of total_bill and tip table shows that Saturday is best day for tips and Friday seems very low level of tips but at the same time we should notice the number of meals servered as well. Friday has the lowest number of meals compared with other days and this could be one the factor for less tips on the day.

# %%
#The following statistics and plots shows the relative distribution of total_bill and tip per person.

# Calculate tip per person. 
#Code adapted from https://stackoverflow.com/a/26050459
tip_per_person = temptips.apply(lambda row: np.round(row.tip/row.party_size,2), axis=1)
# Display the min, max, mean and median total_bill per person
print("\nTotal_bill per person value summary: Max {:5.2f}, Min {:5.2f}, Mean {:5.2f} and Median {:5.2f}".format(
       tip_per_person.max(), tip_per_person.min(), tip_per_person.mean(), tip_per_person.median()))

# Calculate total_bill per person. 
# Code adapted from  https://stackoverflow.com/a/26050459
bill_per_person = temptips.apply(lambda row: np.round(row.total_bill/row.party_size,2), axis=1)
# Display the min, max, mean and median tip per person
print("Tip value per person summary:        Max {:5.2f}, Min {:5.2f}, Mean {:5.2f} and Median {:5.2f}".format(
       bill_per_person.max(), bill_per_person.min(), bill_per_person.mean(), bill_per_person.median()))

# Code adapted from https://seaborn.pydata.org/generated/seaborn.jointplot.html
plot = sns.jointplot(x=bill_per_person, y=tip_per_person, kind="reg", height=8, color="k").set_axis_labels(
                                "total_bill per person", "tip per person")

# Add Title adapted from https://stackoverflow.com/a/52096280
plt.subplots_adjust(top=0.95)
plt.suptitle("Total_bill versus tip per person", fontsize = 16)
plt.show()
# Out:
# Total_bill per person value summary: Max  3.33, Min  0.40, Mean  1.21 and Median  1.11
# Tip value per person summary:        Max 20.27, Min  2.88, Mean  7.89 and Median  7.25

# %% [markdown]
# The above example shows that the tip received is directly proportional to the amount of the total_bill, which can be approximated by the equation. The frequency of tips per person with values around 0.5 and 1.5 has the data points along the clustered line.  From the histogram bar on the vertical axis we can find that the aproximate tip given by the person is around $1.00.

# %% [markdown]
# #### Summary of the analysis:
#
# - I have highlighted the following points based on the above analysis on the 'tips' dataset.
#
# - The data from the restuarant could be taken by the waiter or by the person at the till only from Thursday to Sunday.
#
# - The recorded days could be the busiest days in the week or the restaurant may be closed from Monday to Wednesday
#
# - Saturday is the best day and Friday is the worst day with less number of meals serverd, tip and total_bill received.
#
# - The busy time on Thursday is Lunch time, mixed on Friday and exclusively Dinner time on Saturday and Sunday.
#
# - Smokers at Dinner time with party size 2 has the highest rate of Total bill with tip amount
#
# - The majority of tables have 2 people per table
#
# - Smokers tend to spend more and tip slightly better than non-smokers.

# %% [markdown]
# ## References
#
# #### Discriptive Statistics
#
# https://www.edvancer.in/descriptive-statistics-for-data-science/?fireglass_rsn=true
#
# https://blog.softhints.com/pandas-count-percentage-value-column/
#
# https://github.com/mwaskom/seaborn/issues/1027?fireglass_rsn=true
#
# https://dataconomy.com/2017/06/frequency-distribution-analysis-python-2/?fireglass_rsn=true
#
# https://www.pluralsight.com/guides/interpreting-data-using-descriptive-statistics-python?fireglass_rsn=true
#
# https://docs.python.org/3/library/statistics.html?fireglass_rsn=true
#
# https://www.statisticshowto.datasciencecentral.com/how-to-make-a-frequency-chart-and-determine-frequency/?fireglass_rsn=true
#
#
# #### Regression
#
# https://seaborn.pydata.org/generated/seaborn.pairplot.html
#
# https://seaborn.pydata.org/tutorial/regression.html?fireglass_rsn=true
#
# https://courses.lumenlearning.com/introstats1/chapter/when-to-use-each-measure-of-central-tendency/?fireglass_rsn=true
#
# https://www.kaggle.com/ranjeetjain3/seaborn-tips-dataset?fireglass_rsn=true
#
# http://rstudio-pubs-static.s3.amazonaws.com/128623_507fbe51532748f29278825fceedab85.html?fireglass_rsn=true
#
# https://www.tutor2u.net/psychology/topics/measures-of-dispersion?fireglass_rsn=true
#
# http://seaborn.pydata.org/generated/seaborn.regplot.html?highlight=reg
#
#
# #### Analysis
#
# https://data-and-design.readthedocs.io/en/latest/02-introPandas.html?fireglass_rsn=true
#
# https://dfrieds.com/data-analysis/crosstabs-python-pandas
#
# https://www.datacamp.com/community/tutorials/pandas-multi-index?fireglass_rsn=true
#
# https://stackoverflow.com/questions/17950374/converting-a-column-within-pandas-dataframe-from-int-to-string?fireglass_rsn=true
#
# https://www.datacamp.com/community/tutorials/pandas-multi-index?fireglass_rsn=true
#
# https://pandas.pydata.org/pandas-docs/stable/getting_started/comparison/comparison_with_sql.html
